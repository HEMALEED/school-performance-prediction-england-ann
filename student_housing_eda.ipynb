# %% [markdown]
# # Week 1 Practical: Automated Housing EDA

# %% [markdown]
# # 1. Business Understanding
# Assign your answers inside the dictionary below.

# %%
# DO NOT CHANGE THE VARIABLE NAME
business_understanding = {
    "stakeholder": "YOUR ANSWER HERE",
    "policy_problem": "YOUR ANSWER HERE",
    "analytical_objective": "YOUR ANSWER HERE",
    "success_criteria": "YOUR ANSWER HERE"
}

# %% [markdown]
# # 2. Load and Inspect Data

# %%
from pathlib import Path
import tarfile
import urllib.request
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def load_housing_data():
    tarball_path = Path("datasets/housing.tgz")
    if not tarball_path.is_file():
        Path("datasets").mkdir(parents=True, exist_ok=True)
        url = "https://github.com/ageron/data/raw/main/housing.tgz"
        urllib.request.urlretrieve(url, tarball_path)
    with tarfile.open(tarball_path) as housing_tarball:
        housing_tarball.extractall(path="datasets")
    return pd.read_csv(Path("datasets/housing/housing.csv"))

housing = load_housing_data()

# %%
# Task: Display head, shape, and missing value counts
# Your code here

# %% [markdown]
# # 3. Dataset Overview Notes
# Summarize data quirks (e.g., missing fields, capped values) in the string variable below.

# %%
# DO NOT CHANGE THE VARIABLE NAME
dataset_overview_notes = """
YOUR DATA QUALITY PARAGRAPH HERE
"""

# %% [markdown]
# # 4. Feature Engineering
# Generate rooms_per_house, bedrooms_ratio, and people_per_house columns.

# %%
# Your code here to modify the 'housing' dataframe

# %% [markdown]
# # 5. Preliminary Insights
# Provide exactly 5 distinct insights as strings inside this list.

# %%
# DO NOT CHANGE THE VARIABLE NAME
preliminary_insights = [
    "Insight 1 here",
    "Insight 2 here",
    "Insight 3 here",
    "Insight 4 here",
    "Insight 5 here"
]

# %% [markdown]
# # 6. Limitations and Next Steps

# %%
# DO NOT CHANGE THE VARIABLE NAMES
limitations = ["Limitation 1", "Limitation 2"]
next_steps = ["Step 1", "Step 2"]
